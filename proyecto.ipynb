# %% [markdown]
# <a href="https://colab.research.google.com/github/yessss28/Estadistica/blob/main/proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv ('https://raw.githubusercontent.com/yessss28/Estadistica/refs/heads/main/test.csv')
df.dropna(inplace=True)
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
df.drop(columns = ['id'], inplace = True)
df
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 1              841     1          0.5         1   4       1          61
# 2             1807     1          2.8         0   1       0          27
# 3             1546     0          0.5         1  18       1          25
# 4             1434     0          1.4         0  11       1          49
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# # battery_power

# %%
df['battery_power'].unique()
# Out:
# array([1043,  841, 1807, 1546, 1434, 1464, 1718,  833, 1111, 1520, 1500,
#        1343,  900, 1190,  630, 1846, 1985, 1042, 1231, 1488,  968,  529,
#        1558,  533, 1037, 1025, 1858,  980,  644, 1024, 1981, 1380, 1557,
#        1201, 1074, 1175, 1280, 1715, 1165,  567, 1952,  822,  685, 1388,
#        1972, 1411, 1094, 1653,  916, 1712,  882,  632, 1442, 1630, 1596,
#        1272, 1640, 1889, 1907,  578, 1634, 1533,  660, 1847, 1206,  549,
#        1705, 1366, 1991, 1102, 1452, 1810, 1166,  881, 1134, 1031, 1376,
#        1391,  979, 1075, 1999, 1626,  942, 1182, 1982, 1373, 1151, 1650,
#        1663, 1965,  679, 1465, 1809,  757, 1034, 1119,  559, 1204, 1008,
#        1397,  697, 1939, 1039, 1605,  769,  861,  504, 1930, 1795, 1363,
#        1901, 1319,  859, 1664,  955,  517, 1806, 1348, 1455, 1611, 1573,
#         557, 1599, 1051, 1857, 1986,  591, 1140,  923, 1582,  723, 1251,
#         574,  948, 1571,  564, 1466,  597,  895, 1535, 1832, 1045, 1483,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['battery_power'], kde = True, color = 'pink')
plt.title('Histograma de battery_power')
plt.xlabel('battery_power')
plt.ylabel('Frecuencia')
plt.title('Distribucion de frecuencia')

plt.gca().spines[['right']].set_visible(False)
plt.gca().spines[['top']].set_visible(False)

# no existen datos atipicos

# %% [markdown]
# # blue

# %%
df['blue'].unique()
# Out:
# array([1, 0])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(blue)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#              df        sum_sq        mean_sq         F    PR(>F)
# C(blue)     1.0  4.058870e+05  405887.011442  2.172833  0.140783
# Residual  998.0  1.864272e+08  186800.812514       NaN       NaN

# %%
df.drop(columns = ['blue'], inplace = True)
df
# Out:
#      battery_power  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0             1043          1.8         1  14       0           5    0.1
# 1              841          0.5         1   4       1          61    0.8
# 2             1807          2.8         0   1       0          27    0.9
# 3             1546          0.5         1  18       1          25    0.5
# 4             1434          1.4         0  11       1          49    0.5
# ..             ...          ...       ...  ..     ...         ...    ...
# 995           1700          1.9         0   0       1          54    0.5
# 996            609          1.8         1   0       0          13    0.9
# 997           1185          1.4         0   1       1           8    0.5
# 998           1533          0.5         1   0       0          50    0.4
# 999           1270          0.5         0   4       1          35    0.1
#
#      mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %% [markdown]
# # clock_speed

# %%
df['clock_speed'].unique()
# Out:
# array([1.8, 0.5, 2.8, 1.4, 2.9, 2.4, 2.2, 1. , 1.7, 2.6, 0.6, 0.7, 1.6,
#        3. , 1.2, 2.1, 0.9, 2.3, 2. , 0.8, 1.9, 2.5, 1.1, 2.7, 1.3, 1.5])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(clock_speed)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#                    df        sum_sq        mean_sq         F    PR(>F)
# C(clock_speed)   25.0  3.978615e+06  159144.585847  0.847706  0.680736
# Residual        974.0  1.828545e+08  187735.609090       NaN       NaN

# %%
df.drop(columns = ['clock_speed'], inplace = True)
df
# Out:
#      battery_power  dual_sim  fc  four_g  int_memory  m_dep  mobile_wt  \
# 0             1043         1  14       0           5    0.1        193
# 1              841         1   4       1          61    0.8        191
# 2             1807         0   1       0          27    0.9        186
# 3             1546         1  18       1          25    0.5         96
# 4             1434         0  11       1          49    0.5        108
# ..             ...       ...  ..     ...         ...    ...        ...
# 995           1700         0   0       1          54    0.5        170
# 996            609         1   0       0          13    0.9        186
# 997           1185         0   1       1           8    0.5         80
# 998           1533         1   0       0          50    0.4        171
# 999           1270         0   4       1          35    0.1        140
#
#      n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# ...

# %% [markdown]
# # dual_sim

# %%
df['dual_sim'].unique()
# Out:
# array([1, 0])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(dual_sim)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#                 df        sum_sq        mean_sq         F   PR(>F)
# C(dual_sim)    1.0  6.991068e+05  699106.761532  3.748421  0.05314
# Residual     998.0  1.861340e+08  186507.005149       NaN      NaN

# %% [markdown]
# # fc

# %%
df['fc'].unique()
# Out:
# array([14,  4,  1, 18, 11,  5,  0,  9,  2,  8,  7, 16,  6, 15, 10,  3, 12,
#        13, 17, 19])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(fc)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#              df        sum_sq        mean_sq         F    PR(>F)
# C(fc)      19.0  1.982822e+06  104359.028894  0.553269  0.938151
# Residual  980.0  1.848503e+08  188622.730970       NaN       NaN

# %%
df.drop(columns = ['fc'], inplace = True)
df
# Out:
#      battery_power  dual_sim  four_g  int_memory  m_dep  mobile_wt  n_cores  \
# 0             1043         1       0           5    0.1        193        3
# 1              841         1       1          61    0.8        191        5
# 2             1807         0       0          27    0.9        186        3
# 3             1546         1       1          25    0.5         96        8
# 4             1434         0       1          49    0.5        108        6
# ..             ...       ...     ...         ...    ...        ...      ...
# 995           1700         0       1          54    0.5        170        7
# 996            609         1       0          13    0.9        186        4
# 997           1185         0       1           8    0.5         80        1
# 998           1533         1       0          50    0.4        171        2
# 999           1270         0       1          35    0.1        140        6
#
# ...

# %% [markdown]
# # four_g

# %%
df['four_g'].unique()
# Out:
# array([0, 1])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(four_g)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#               df        sum_sq        mean_sq         F    PR(>F)
# C(four_g)    1.0  3.377859e+05  337785.918388  1.807608  0.179101
# Residual   998.0  1.864953e+08  186869.050082       NaN       NaN

# %%
df.drop(columns = ['four_g'], inplace = True)
df
# Out:
#      battery_power  dual_sim  int_memory  m_dep  mobile_wt  n_cores  pc  \
# 0             1043         1           5    0.1        193        3  16
# 1              841         1          61    0.8        191        5  12
# 2             1807         0          27    0.9        186        3   4
# 3             1546         1          25    0.5         96        8  20
# 4             1434         0          49    0.5        108        6  18
# ..             ...       ...         ...    ...        ...      ...  ..
# 995           1700         0          54    0.5        170        7  17
# 996            609         1          13    0.9        186        4   2
# 997           1185         0           8    0.5         80        1  12
# 998           1533         1          50    0.4        171        2  12
# 999           1270         0          35    0.1        140        6  19
#
#      px_height  px_width   ram  sc_h  sc_w  talk_time  three_g  touch_screen  \
# ...

# %% [markdown]
# # int_memory

# %%
df['int_memory'].unique()
# Out:
# array([ 5, 61, 27, 25, 49, 50, 47, 62, 55, 34, 30, 19, 51, 53, 26, 48, 37,
#         7, 60, 58, 43, 17,  8, 15, 38, 11, 56, 32, 45, 33, 28, 40,  2, 12,
#        57, 20, 13, 29, 24, 54, 22, 39, 10, 23, 36, 63, 41,  6, 64, 42, 44,
#         3, 52, 16, 31, 14, 21,  9, 46,  4, 18, 35, 59])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(int_memory)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#                   df        sum_sq        mean_sq         F    PR(>F)
# C(int_memory)   62.0  1.154660e+07  186235.448030  0.995528  0.488005
# Residual       937.0  1.752865e+08  187072.038551       NaN       NaN

# %%
df.drop(columns = ['int_memory'], inplace = True)
df
# Out:
#      battery_power  dual_sim  m_dep  mobile_wt  n_cores  pc  px_height  \
# 0             1043         1    0.1        193        3  16        226
# 1              841         1    0.8        191        5  12        746
# 2             1807         0    0.9        186        3   4       1270
# 3             1546         1    0.5         96        8  20        295
# 4             1434         0    0.5        108        6  18        749
# ..             ...       ...    ...        ...      ...  ..        ...
# 995           1700         0    0.5        170        7  17        644
# 996            609         1    0.9        186        4   2       1152
# 997           1185         0    0.5         80        1  12        477
# 998           1533         1    0.4        171        2  12         38
# 999           1270         0    0.1        140        6  19        457
#
#      px_width   ram  sc_h  sc_w  talk_time  three_g  touch_screen  wifi
# ...

# %% [markdown]
# # m_dep

# %%
df['m_dep'].unique()
# Out:
# array([0.1, 0.8, 0.9, 0.5, 1. , 0.6, 0.7, 0.2, 0.3, 0.4])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(m_dep)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#              df        sum_sq        mean_sq         F    PR(>F)
# C(m_dep)    9.0  1.985397e+06  220599.702599  1.181479  0.303102
# Residual  990.0  1.848477e+08  186714.849067       NaN       NaN

# %%
df.drop(columns = ['m_dep'], inplace = True)
df
# Out:
#      battery_power  dual_sim  mobile_wt  n_cores  pc  px_height  px_width  \
# 0             1043         1        193        3  16        226      1412
# 1              841         1        191        5  12        746       857
# 2             1807         0        186        3   4       1270      1366
# 3             1546         1         96        8  20        295      1752
# 4             1434         0        108        6  18        749       810
# ..             ...       ...        ...      ...  ..        ...       ...
# 995           1700         0        170        7  17        644       913
# 996            609         1        186        4   2       1152      1632
# 997           1185         0         80        1  12        477       825
# 998           1533         1        171        2  12         38       832
# 999           1270         0        140        6  19        457       608
#
#       ram  sc_h  sc_w  talk_time  three_g  touch_screen  wifi
# ...

# %% [markdown]
# # mobile_wt

# %%
df['mobile_wt'].unique()
# Out:
# array([193, 191, 186,  96, 108, 198, 156, 111, 101, 171,  80,  87, 158,
#        106, 163, 194, 189, 151, 115,  97, 125, 122, 124,  91, 139,  81,
#        184, 187, 152, 175, 112, 150, 190, 121, 174, 188, 135, 114, 142,
#        149, 103, 165, 153, 133,  90, 164, 172,  83, 134, 173, 185, 109,
#        117, 166, 177, 167, 137, 127, 168, 183,  98, 107,  99, 154, 105,
#        113,  89, 146, 128, 132, 169, 119, 140, 159, 195, 123, 178, 147,
#         92, 197, 130, 100, 102, 131, 200, 116, 192, 155, 148,  82, 141,
#        104, 161,  88, 126,  86, 179, 176, 196,  93, 162, 199, 143, 138,
#        157,  95, 160, 145, 129, 120, 136, 180, 144,  85, 181, 170,  94,
#         84, 110, 118, 182])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['mobile_wt'], kde = True, color = 'pink')
plt.title('Histograma de mobile_wt')
plt.xlabel('mobile_wt')
plt.ylabel('Frecuencia')
plt.title('Distribucion de frecuencia')

plt.gca().spines[['right']].set_visible(False)
plt.gca().spines[['top']].set_visible(False)

# no existen datos atipicos

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(mobile_wt)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#                  df        sum_sq        mean_sq        F    PR(>F)
# C(mobile_wt)  120.0  1.752212e+07  146017.695580  0.75807  0.971721
# Residual      879.0  1.693110e+08  192617.718351      NaN       NaN

# %%
df.drop(columns = ['mobile_wt'], inplace = True)
df
# Out:
#      battery_power  dual_sim  n_cores  pc  px_height  px_width   ram  sc_h  \
# 0             1043         1        3  16        226      1412  3476    12
# 1              841         1        5  12        746       857  3895     6
# 2             1807         0        3   4       1270      1366  2396    17
# 3             1546         1        8  20        295      1752  3893    10
# 4             1434         0        6  18        749       810  1773    15
# ..             ...       ...      ...  ..        ...       ...   ...   ...
# 995           1700         0        7  17        644       913  2121    14
# 996            609         1        4   2       1152      1632  1933     8
# 997           1185         0        1  12        477       825  1223     5
# 998           1533         1        2  12         38       832  2509    15
# 999           1270         0        6  19        457       608  2828     9
#
#      sc_w  talk_time  three_g  touch_screen  wifi
# ...

# %% [markdown]
# # n_cores

# %%
df['n_cores'].unique()
# Out:
# array([3, 5, 8, 6, 2, 1, 7, 4])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(n_cores)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#                df        sum_sq        mean_sq        F    PR(>F)
# C(n_cores)    7.0  1.826084e+06  260869.203067  1.39877  0.202112
# Residual    992.0  1.850070e+08  186499.005523      NaN       NaN

# %%
df.drop(columns = ['n_cores'], inplace = True)
df
# Out:
#      battery_power  dual_sim  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0             1043         1  16        226      1412  3476    12     7
# 1              841         1  12        746       857  3895     6     0
# 2             1807         0   4       1270      1366  2396    17    10
# 3             1546         1  20        295      1752  3893    10     0
# 4             1434         0  18        749       810  1773    15     8
# ..             ...       ...  ..        ...       ...   ...   ...   ...
# 995           1700         0  17        644       913  2121    14     8
# 996            609         1   2       1152      1632  1933     8     1
# 997           1185         0  12        477       825  1223     5     0
# 998           1533         1  12         38       832  2509    15    11
# 999           1270         0  19        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi
# 0            2        0             1     0
# ...

# %% [markdown]
# # pc

# %%
df['pc'].unique()
# Out:
# array([16, 12,  4, 20, 18,  9,  3,  2, 19,  6, 15,  7, 17,  5, 10,  1,  0,
#        13, 11,  8, 14])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(pc)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#              df        sum_sq        mean_sq         F    PR(>F)
# C(pc)      20.0  3.802515e+06  190125.756240  1.016951  0.438385
# Residual  979.0  1.830306e+08  186956.672906       NaN       NaN

# %%
df.drop(columns = ['pc'], inplace = True)
df
# Out:
#      battery_power  dual_sim  px_height  px_width   ram  sc_h  sc_w  \
# 0             1043         1        226      1412  3476    12     7
# 1              841         1        746       857  3895     6     0
# 2             1807         0       1270      1366  2396    17    10
# 3             1546         1        295      1752  3893    10     0
# 4             1434         0        749       810  1773    15     8
# ..             ...       ...        ...       ...   ...   ...   ...
# 995           1700         0        644       913  2121    14     8
# 996            609         1       1152      1632  1933     8     1
# 997           1185         0        477       825  1223     5     0
# 998           1533         1         38       832  2509    15    11
# 999           1270         0        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi
# 0            2        0             1     0
# 1            7        1             0     0
# ...

# %% [markdown]
# # px_height

# %%
df['px_height'].unique()
# Out:
# array([ 226,  746, 1270,  295,  749,  569, 1283, 1312,  556,   52,  503,
#         235,  829,  227, 1315,  185,  613,  335,   82,   47,  504,  521,
#         777,  512, 1194, 1003,  575,   54,  627,  129,  876,  501, 1407,
#         722, 1219,  119,  753,  162,  313,  181, 1416,  645,   79,  153,
#         480,  700,  221, 1585,   65,  224,  705,  709,   97, 1131,  359,
#        1813,  839,  550,  443,  502,  130,   19,  386,   22,   49, 1497,
#        1327,  555, 1560,  346,  912,  756,  699,  582,  680,  814,  672,
#         450,  757,  208, 1335,   91,   33, 1095,  336,  659,  183,  652,
#         410,  440,  532, 1373,  773,  965,  568,  214,  423,  537,  667,
#         491, 1037,  325, 1324,  597,  765,  470,  653,  463,  855,  492,
#         605,  401,  366, 1225,  573,  261,  280,  565, 1379,  949,  703,
#        1264, 1816,  108, 1328,  797,  361, 1049,  357,  197,  906,  806,
#         924,  223,  140,  113, 1531,   35, 1524,  838,  495, 1212,  655,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['px_height'], kde = True, color = 'pink')
plt.title('Histograma de px_height')
plt.xlabel('px_height')
plt.ylabel('Frecuencia')
plt.title('Distribucion de frecuencia')

plt.gca().spines[['right']].set_visible(False)
plt.gca().spines[['top']].set_visible(False)

# no existen datos atipicos

# %% [markdown]
# # px_width

# %%
df['px_width'].unique()
# Out:
# array([1412,  857, 1366, 1752,  810,  939, 1374, 1880,  876, 1009, 1336,
#        1671, 1893, 1856, 1323, 1832, 1511,  532, 1771,  559, 1930, 1591,
#        1587, 1111, 1321, 1306, 1200,  658,  630, 1048, 1408,  643, 1633,
#         992, 1904, 1777, 1557,  847,  528,  566, 1892,  851,  633,  972,
#         748, 1234,  610, 1896, 1867,  816,  764, 1695,  663, 1360, 1022,
#        1871, 1788,  666,  755, 1113,  647,  667,  636, 1345, 1552, 1508,
#        1361, 1386, 1808,  702, 1660,  882, 1704, 1078, 1015, 1597,  911,
#        1371,  900, 1256, 1427, 1585,  653, 1499,  797,  661,  709, 1100,
#        1014, 1416,  886, 1949,  920,  974, 1864, 1157, 1463, 1003,  627,
#        1872,  692, 1829, 1945,  921,  836, 1115, 1062, 1609, 1205,  910,
#        1684, 1110,  769, 1989, 1821, 1358,  856,  538, 1138,  683, 1443,
#        1673, 1297, 1682, 1917,  894, 1743, 1061,  555, 1715, 1718, 1801,
#        1405, 1498, 1148,  718,  863, 1727,  708, 1691, 1667,  596, 1772,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['px_width'], kde = True, color = 'pink')
plt.title('Histograma de px_width')
plt.xlabel('px_width')
plt.ylabel('Frecuencia')
plt.title('Distribucion de frecuencia')

plt.gca().spines[['right']].set_visible(False)
plt.gca().spines[['top']].set_visible(False)

# no existen datos atipicos

# %% [markdown]
# # ram

# %%
df['ram'].unique()
# Out:
# array([3476, 3895, 2396, 3893, 1773, 3506, 3873, 1495, 3485,  651, 3866,
#        3911,  439,  992, 2751,  563, 2083, 2187, 3902, 2524, 1357, 3456,
#        1641, 2322, 3862,  557, 2427,  625, 3836,  854, 2383,  926, 3048,
#         824,  874, 1617, 3309, 1786, 3128, 2243,  994, 2749,  793,  324,
#         366, 1228, 1413, 2617, 1798, 2693, 2437,  837, 2815, 1440, 3470,
#        1251, 3181, 1361, 1630, 3689, 3586, 3942, 1431, 2167, 1248, 1986,
#        1378, 2959, 1893, 1676, 1912, 1947, 2734, 3617, 3414,  482, 2813,
#         661, 2546, 3922, 1199, 3779, 3870,  858, 3840,  454, 3953, 1633,
#        3035,  966, 1761, 1938, 2820,  305, 2838, 2042,  700, 2593, 1835,
#        3121, 2023,  737,  450, 2928, 1694,  745, 1310, 2743, 3976, 3931,
#        3455, 1533, 3876, 3239, 3628, 3663, 3502,  815,  275, 3758, 2747,
#        1809, 2086,  444, 3467, 2776, 3170, 1234, 1745, 1707, 2220, 3130,
#        1500, 2145,  488, 3863, 2913, 2094, 3141, 2573, 2340, 3788, 3445,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['ram'], kde = True, color = 'pink')
plt.title('Histograma de ram')
plt.xlabel('ram')
plt.ylabel('Frecuencia')
plt.title('Distribucion de frecuencia')

plt.gca().spines[['right']].set_visible(False)
plt.gca().spines[['top']].set_visible(False)

# no existen datos atipicos

# %%
df
# Out:
#      battery_power  dual_sim  px_height  px_width   ram  sc_h  sc_w  \
# 0             1043         1        226      1412  3476    12     7
# 1              841         1        746       857  3895     6     0
# 2             1807         0       1270      1366  2396    17    10
# 3             1546         1        295      1752  3893    10     0
# 4             1434         0        749       810  1773    15     8
# ..             ...       ...        ...       ...   ...   ...   ...
# 995           1700         0        644       913  2121    14     8
# 996            609         1       1152      1632  1933     8     1
# 997           1185         0        477       825  1223     5     0
# 998           1533         1         38       832  2509    15    11
# 999           1270         0        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi
# 0            2        0             1     0
# 1            7        1             0     0
# ...

# %% [markdown]
# # sc_h

# %%
df['sc_h'].unique()
# Out:
# array([12,  6, 17, 10, 15, 14,  7, 11, 13,  9, 19,  5, 16, 18,  8])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(sc_h)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#se rechaza la hipotesis nula
# Out:
#              df        sum_sq        mean_sq         F    PR(>F)
# C(sc_h)    14.0  5.859157e+06  418511.237791  2.277861  0.004602
# Residual  985.0  1.809739e+08  183729.888904       NaN       NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
nivel_significanica = 0.05

tukey = pairwise_tukeyhsd(endog=df['battery_power'], groups=df['sc_h'],
                          alpha=0.05)
tukey.plot_simultaneous(ylabel='nivel de medicion', xlabel = 'unidades de variable' )

plt.gca().spines[['right']].set_visible(False)
plt.gca().spines[['top']].set_visible(False)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %% [markdown]
# # sc_w

# %%
df['sc_w'].unique()
# Out:
# array([ 7,  0, 10,  8,  2,  9,  6,  5,  3, 12,  1, 11,  4, 13, 16, 14, 15,
#        17, 18])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(sc_w)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#              df        sum_sq        mean_sq         F    PR(>F)
# C(sc_w)    18.0  2.443862e+06  135770.138837  0.722333  0.790286
# Residual  981.0  1.843892e+08  187960.484608       NaN       NaN

# %%
df.drop(columns = ['sc_w'], inplace = True)
df
# Out:
#      battery_power  dual_sim  px_height  px_width   ram  sc_h  talk_time  \
# 0             1043         1        226      1412  3476    12          2
# 1              841         1        746       857  3895     6          7
# 2             1807         0       1270      1366  2396    17         10
# 3             1546         1        295      1752  3893    10          7
# 4             1434         0        749       810  1773    15          7
# ..             ...       ...        ...       ...   ...   ...        ...
# 995           1700         0        644       913  2121    14         15
# 996            609         1       1152      1632  1933     8         19
# 997           1185         0        477       825  1223     5         14
# 998           1533         1         38       832  2509    15          6
# 999           1270         0        457       608  2828     9          3
#
#      three_g  touch_screen  wifi
# 0          0             1     0
# ...

# %% [markdown]
# # talk_time

# %%
df['talk_time'].unique()
# Out:
# array([ 2,  7, 10,  3, 18,  5, 20,  8, 16, 14, 15,  6,  9, 13, 12, 17, 11,
#         4, 19])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(talk_time)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#                  df        sum_sq        mean_sq         F    PR(>F)
# C(talk_time)   18.0  2.548885e+06  141604.711313  0.753804  0.755711
# Residual      981.0  1.842842e+08  187853.428233       NaN       NaN

# %%
df.drop(columns = ['talk_time'], inplace = True)
df
# Out:
#      battery_power  dual_sim  px_height  px_width   ram  sc_h  three_g  \
# 0             1043         1        226      1412  3476    12        0
# 1              841         1        746       857  3895     6        1
# 2             1807         0       1270      1366  2396    17        0
# 3             1546         1        295      1752  3893    10        1
# 4             1434         0        749       810  1773    15        1
# ..             ...       ...        ...       ...   ...   ...      ...
# 995           1700         0        644       913  2121    14        1
# 996            609         1       1152      1632  1933     8        0
# 997           1185         0        477       825  1223     5        1
# 998           1533         1         38       832  2509    15        0
# 999           1270         0        457       608  2828     9        1
#
#      touch_screen  wifi
# 0               1     0
# 1               0     0
# 2               1     1
# ...

# %% [markdown]
# # three_g

# %%
df['three_g'].unique()
# Out:
# array([0, 1])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(three_g)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#                df        sum_sq        mean_sq         F    PR(>F)
# C(three_g)    1.0  1.855519e+05  185551.913618  0.992142  0.319461
# Residual    998.0  1.866475e+08  187021.589165       NaN       NaN

# %%
df.drop(columns = ['three_g'], inplace = True)
df
# Out:
#      battery_power  dual_sim  px_height  px_width   ram  sc_h  touch_screen  \
# 0             1043         1        226      1412  3476    12             1
# 1              841         1        746       857  3895     6             0
# 2             1807         0       1270      1366  2396    17             1
# 3             1546         1        295      1752  3893    10             1
# 4             1434         0        749       810  1773    15             0
# ..             ...       ...        ...       ...   ...   ...           ...
# 995           1700         0        644       913  2121    14             1
# 996            609         1       1152      1632  1933     8             1
# 997           1185         0        477       825  1223     5             0
# 998           1533         1         38       832  2509    15             1
# 999           1270         0        457       608  2828     9             0
#
#      wifi
# 0       0
# 1       0
# 2       1
# ...

# %% [markdown]
# # touch_screen

# %%
df['touch_screen'].unique()
# Out:
# array([1, 0])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(touch_screen)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#                     df        sum_sq        mean_sq         F    PR(>F)
# C(touch_screen)    1.0  1.920192e+04   19201.924000  0.102581  0.748821
# Residual         998.0  1.868139e+08  187188.272521       NaN       NaN

# %%
df.drop(columns = ['touch_screen'], inplace = True)
df
# Out:
#      battery_power  dual_sim  px_height  px_width   ram  sc_h  wifi
# 0             1043         1        226      1412  3476    12     0
# 1              841         1        746       857  3895     6     0
# 2             1807         0       1270      1366  2396    17     1
# 3             1546         1        295      1752  3893    10     0
# 4             1434         0        749       810  1773    15     1
# ..             ...       ...        ...       ...   ...   ...   ...
# 995           1700         0        644       913  2121    14     0
# 996            609         1       1152      1632  1933     8     1
# 997           1185         0        477       825  1223     5     0
# 998           1533         1         38       832  2509    15     0
# 999           1270         0        457       608  2828     9     1
#
# [1000 rows x 7 columns]

# %% [markdown]
# # wifi

# %%
df['wifi'].unique()
# Out:
# array([0, 1])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols('battery_power ~ C(wifi)',data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#              df        sum_sq        mean_sq         F    PR(>F)
# C(wifi)     1.0  3.209743e+01      32.097431  0.000171  0.989555
# Residual  998.0  1.868331e+08  187207.480764       NaN       NaN

# %%
df.drop(columns = ['wifi'], inplace = True)
df
# Out:
#      battery_power  dual_sim  px_height  px_width   ram  sc_h
# 0             1043         1        226      1412  3476    12
# 1              841         1        746       857  3895     6
# 2             1807         0       1270      1366  2396    17
# 3             1546         1        295      1752  3893    10
# 4             1434         0        749       810  1773    15
# ..             ...       ...        ...       ...   ...   ...
# 995           1700         0        644       913  2121    14
# 996            609         1       1152      1632  1933     8
# 997           1185         0        477       825  1223     5
# 998           1533         1         38       832  2509    15
# 999           1270         0        457       608  2828     9
#
# [1000 rows x 6 columns]

# %% [markdown]
# # MAPA DE CALOR

# %%
# mapa de calor
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr()
plt.figure(figsize=(15, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True, cbar_kws={"shrink": .8})
plt.title('Mapa de Calor de la Matriz de Correlación')
# Out:
# Text(0.5, 1.0, 'Mapa de Calor de la Matriz de Correlación')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import statsmodels.api as sm
import matplotlib.pyplot as plt


X = df[['dual_sim',	'px_height',	'px_width',	'ram', 'sc_h']]
Y = df['battery_power']

# Datos de entrenamiento y datos de prueba

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

X_train_constante = sm.add_constant(X_train)
X_test_constante = sm.add_constant(X_test)

modelo = sm.OLS(Y_train, X_train_constante).fit()


Yc = modelo.predict(X_test_constante)

plt.scatter(Y_test, Yc)

r2 = r2_score(Y_test, Yc)
print(f'Coeficiente de correlacion: {r2: 0.4f}\n')
# Out:
# Coeficiente de correlacion: -0.0584

# %%
# Get the number of parameters in the model
num_params = len(modelo.params)

# Unpack the parameters dynamically
params = modelo.params
b0 = params[0]  # Intercept
b1 = params[1]  # dual_sim
b2 = params[2]  # px_height
b3 = params[3]  # px_width
b4 = params[4]  # ram
b5 = params[5] # sc_h

# Update the lambda function to include all parameters
Fun = lambda x1, x2, x3, x4, x5: b0 + b1 * x1 + b2 * x2 + b3 * x3 + b4 * x4 + b5*x5

# Example usage
Fun(100, 250, 600, 2000, 10) # assuming sample values for x1 to x5
# Out:
# <ipython-input-151-7a8b69ace947>:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   b0 = params[0]  # Intercept
# <ipython-input-151-7a8b69ace947>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   b1 = params[1]  # dual_sim
# <ipython-input-151-7a8b69ace947>:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   b2 = params[2]  # px_height
# ...

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# Instead of using 'C()' for every variable, specify the categorical variables separately
# and let statsmodels handle the rest.
modelo = ols('battery_power ~ dual_sim + px_height + px_width + ram + sc_h', data=df).fit()

# Check for any warnings or error messages after fitting the model.
print(modelo.summary())

# Calculate ANOVA table
tabla_anova = sm.stats.anova_lm(modelo, typ=2)  # anova de una sola VIA
tabla_anova
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          battery_power   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     2.227
# Date:                Sun, 13 Apr 2025   Prob (F-statistic):             0.0496
# Time:                        19:57:26   Log-Likelihood:                -7482.4
# No. Observations:                1000   AIC:                         1.498e+04
# Df Residuals:                     994   BIC:                         1.501e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1300.7900     63.591     20.456      0.000    1176.002    1425.578
# ...

# %% [markdown]
# # PUNTOS EXTRA

# %%
promedio = df['battery_power'].mean()
df['mayor_al_promedio'] = (df['battery_power'] > promedio).astype(int)
df
# Out:
#      battery_power  dual_sim  px_height  px_width   ram  sc_h  \
# 0             1043         1        226      1412  3476    12
# 1              841         1        746       857  3895     6
# 2             1807         0       1270      1366  2396    17
# 3             1546         1        295      1752  3893    10
# 4             1434         0        749       810  1773    15
# ..             ...       ...        ...       ...   ...   ...
# 995           1700         0        644       913  2121    14
# 996            609         1       1152      1632  1933     8
# 997           1185         0        477       825  1223     5
# 998           1533         1         38       832  2509    15
# 999           1270         0        457       608  2828     9
#
#      mayor_al_promedio
# 0                    0
# 1                    0
# 2                    1
# 3                    1
# 4                    1
# ..                 ...
# 995                  1
# 996                  0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr()
plt.figure(figsize=(15, 9))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True, cbar_kws={"shrink": 0.8})
plt.xlabel('Variables')
plt.ylabel('Variables')
plt.title('Mapa de Calor de la Matriz de Correlación')
# Out:
# Text(0.5, 1.0, 'Mapa de Calor de la Matriz de Correlación')

# %%
#Selección de variables
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import statsmodels.api as sm
import matplotlib.pyplot as plt

X = df[['wifi', 'dual_sim', 'px_height']]
Y = df['battery_power']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# Crear y entrenar el modelo
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, Y_train)

# Predecir
Y_pred = rf.predict(X_test)

# Evaluar
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          500       0.00      0.00      0.00       1.0
#          507       0.00      0.00      0.00       1.0
#          519       0.00      0.00      0.00       1.0
#          520       0.00      0.00      0.00       1.0
#          524       0.00      0.00      0.00       0.0
#          532       0.00      0.00      0.00       0.0
#          533       0.00      0.00      0.00       1.0
#          535       0.00      0.00      0.00       1.0
#          541       0.00      0.00      0.00       1.0
#          542       0.00      0.00      0.00       1.0
#          543       0.00      0.00      0.00       0.0
#          544       0.00      0.00      0.00       0.0
#          547       0.00      0.00      0.00       1.0
#          560       0.00      0.00      0.00       0.0
#          567       0.00      0.00      0.00       1.0
#          574       0.00      0.00      0.00       1.0
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

importancia = pd.Series(rf.feature_importances_, index=X.columns)
print(importancia.sort_values(ascending=False))
# Out:
# px_height    0.985374
# dual_sim     0.007760
# wifi         0.006867
# dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier

# Crear y entrenar el modelo
modelo_dtc = DecisionTreeClassifier(random_state=42)
modelo_dtc.fit(X_train, Y_train)

# Predecir
Y_pred = modelo_dtc.predict(X_test)

# Evaluar
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          500       0.00      0.00      0.00       1.0
#          507       0.00      0.00      0.00       1.0
#          519       0.00      0.00      0.00       1.0
#          520       0.00      0.00      0.00       1.0
#          524       0.00      0.00      0.00       0.0
#          532       0.00      0.00      0.00       0.0
#          533       0.00      0.00      0.00       1.0
#          535       0.00      0.00      0.00       1.0
#          541       0.00      0.00      0.00       1.0
#          542       0.00      0.00      0.00       1.0
#          544       0.00      0.00      0.00       0.0
#          547       0.00      0.00      0.00       1.0
#          559       0.00      0.00      0.00       0.0
#          560       0.00      0.00      0.00       0.0
#          567       0.00      0.00      0.00       1.0
#          574       0.00      0.00      0.00       1.0
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Crear y entrenar el modelo
modelo_gbc = GradientBoostingClassifier(random_state=42)
modelo_gbc.fit(X_train, Y_train)

# Predecir
Y_pred = modelo_gbc.predict(X_test)

# Evaluar
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          500       0.00      0.00      0.00       1.0
#          507       0.00      0.00      0.00       1.0
#          510       0.00      0.00      0.00       0.0
#          517       0.00      0.00      0.00       0.0
#          519       0.00      0.00      0.00       1.0
#          520       0.00      0.00      0.00       1.0
#          529       0.00      0.00      0.00       0.0
#          533       0.00      0.00      0.00       1.0
#          535       0.00      0.00      0.00       1.0
#          541       0.00      0.00      0.00       1.0
#          542       0.00      0.00      0.00       1.0
#          547       0.00      0.00      0.00       1.0
#          556       0.00      0.00      0.00       0.0
#          560       0.00      0.00      0.00       0.0
#          567       0.00      0.00      0.00       1.0
#          574       0.00      0.00      0.00       1.0
# ...

# %%
from sklearn.ensemble import BaggingClassifier

# Crear y entrenar el modelo
modelo_gc = BaggingClassifier(random_state=42)
modelo_gc.fit(X_train, Y_train)

# Predecir
Y_pred = modelo_gc.predict(X_test)

# Evaluar
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          500       0.00      0.00      0.00       1.0
#          507       0.00      0.00      0.00       1.0
#          519       0.00      0.00      0.00       1.0
#          520       0.00      0.00      0.00       1.0
#          524       0.00      0.00      0.00       0.0
#          533       0.00      0.00      0.00       1.0
#          535       0.00      0.00      0.00       1.0
#          541       0.00      0.00      0.00       1.0
#          542       0.00      0.00      0.00       1.0
#          543       0.00      0.00      0.00       0.0
#          544       0.00      0.00      0.00       0.0
#          547       0.00      0.00      0.00       1.0
#          560       0.00      0.00      0.00       0.0
#          564       0.00      0.00      0.00       0.0
#          567       0.00      0.00      0.00       1.0
#          574       0.00      0.00      0.00       1.0
# ...

# %%
from sklearn.ensemble import ExtraTreesClassifier

# Crear y entrenar el modelo
modelo_etc = ExtraTreesClassifier(random_state=42)
modelo_etc.fit(X_train, Y_train)

# Predecir
Y_pred = modelo_etc.predict(X_test)

# Evaluar
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          500       0.00      0.00      0.00       1.0
#          507       0.00      0.00      0.00       1.0
#          519       0.00      0.00      0.00       1.0
#          520       0.00      0.00      0.00       1.0
#          524       0.00      0.00      0.00       0.0
#          532       0.00      0.00      0.00       0.0
#          533       0.00      0.00      0.00       1.0
#          535       0.00      0.00      0.00       1.0
#          541       0.00      0.00      0.00       1.0
#          542       0.00      0.00      0.00       1.0
#          543       0.00      0.00      0.00       0.0
#          544       0.00      0.00      0.00       0.0
#          547       0.00      0.00      0.00       1.0
#          559       0.00      0.00      0.00       0.0
#          560       0.00      0.00      0.00       0.0
#          567       0.00      0.00      0.00       1.0
# ...

# %%
from sklearn.neural_network import MLPClassifier

# Crear el modelo MLP
modelo_nn = MLPClassifier(
    hidden_layer_sizes=(100,),     # Una capa oculta con 100 neuronas
    activation='relu',             # Función de activación
    solver='adam',                 # Algoritmo de optimización
    max_iter=1000,                  # Número máximo de épocas
    random_state=42
)

# Entrenar
modelo_nn.fit(X_train, Y_train)

# Predecir
Y_pred = modelo_nn.predict(X_test)

# Evaluar
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          500       0.00      0.00      0.00       1.0
#          507       0.00      0.00      0.00       1.0
#          519       0.00      0.00      0.00       1.0
#          520       0.00      0.00      0.00       1.0
#          533       0.00      0.00      0.00       1.0
#          535       0.00      0.00      0.00       1.0
#          541       0.00      0.00      0.00       1.0
#          542       0.00      0.00      0.00       1.0
#          547       0.00      0.00      0.00       1.0
#          567       0.00      0.00      0.00       1.0
#          574       0.00      0.00      0.00       1.0
#          579       0.00      0.00      0.00       1.0
#          582       0.00      0.00      0.00       1.0
#          583       0.00      0.00      0.00       1.0
#          617       0.00      0.00      0.00       1.0
#          624       0.00      0.00      0.00       0.0
# ...

# %%
from sklearn.naive_bayes import GaussianNB

# Crear el modelo
modelo_nb = GaussianNB()

# Entrenar
modelo_nb.fit(X_train, Y_train)

# Predecir
y_pred_nb = modelo_nb.predict(X_test)

# Evaluar
print("Naive Bayes")
print(classification_report(Y_test, y_pred_nb))
# Out:
# Naive Bayes
#               precision    recall  f1-score   support
#
#          500       0.00      0.00      0.00       1.0
#          507       0.00      0.00      0.00       1.0
#          519       0.00      0.00      0.00       1.0
#          520       0.00      0.00      0.00       1.0
#          533       0.00      0.00      0.00       1.0
#          534       0.00      0.00      0.00       0.0
#          535       0.00      0.00      0.00       1.0
#          541       0.00      0.00      0.00       1.0
#          542       0.00      0.00      0.00       1.0
#          547       0.00      0.00      0.00       1.0
#          567       0.00      0.00      0.00       1.0
#          574       0.00      0.00      0.00       1.0
#          579       0.00      0.00      0.00       1.0
#          582       0.00      0.00      0.00       1.0
#          583       0.00      0.00      0.00       1.0
#          597       0.00      0.00      0.00       0.0
# ...

# %%
from sklearn.naive_bayes import BernoulliNB

# Crear el modelo
modelo_nb_2 = BernoulliNB()

# Entrenar
modelo_nb_2.fit(X_train, Y_train)

# Predecir
y_pred_nb = modelo_nb_2.predict(X_test)

# Evaluar
print("Naive Bayes")
print(classification_report(Y_test, y_pred_nb))
# Out:
# Naive Bayes
#               precision    recall  f1-score   support
#
#          500       0.00      0.00      0.00         1
#          507       0.00      0.00      0.00         1
#          519       0.00      0.00      0.00         1
#          520       0.00      0.00      0.00         1
#          533       0.00      0.00      0.00         1
#          535       0.00      0.00      0.00         1
#          541       0.00      0.00      0.00         1
#          542       0.00      0.00      0.00         1
#          547       0.00      0.00      0.00         1
#          567       0.00      0.00      0.00         1
#          574       0.00      0.00      0.00         1
#          579       0.00      0.00      0.00         1
#          582       0.00      0.00      0.00         1
#          583       0.00      0.00      0.00         1
#          617       0.00      0.00      0.00         1
#          635       0.00      0.00      0.00         1
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# Crear el modelo
modelo_knn = KNeighborsClassifier(n_neighbors=5)  # Puedes ajustar el valor de k

# Entrenar
modelo_knn.fit(X_train, Y_train)

# Predecir
y_pred_knn = modelo_knn.predict(X_test)

# Evaluar
print("K-Nearest Neighbors")
print(classification_report(Y_test, y_pred_knn))
# Out:
# K-Nearest Neighbors
#               precision    recall  f1-score   support
#
#          500       0.00      0.00      0.00       1.0
#          507       0.00      0.00      0.00       1.0
#          510       0.00      0.00      0.00       0.0
#          511       0.00      0.00      0.00       0.0
#          517       0.00      0.00      0.00       0.0
#          519       0.00      0.00      0.00       1.0
#          520       0.00      0.00      0.00       1.0
#          521       0.00      0.00      0.00       0.0
#          524       0.00      0.00      0.00       0.0
#          529       0.00      0.00      0.00       0.0
#          533       0.00      0.00      0.00       1.0
#          535       0.00      0.00      0.00       1.0
#          536       0.00      0.00      0.00       0.0
#          541       0.00      0.00      0.00       1.0
#          542       0.00      0.00      0.00       1.0
#          544       0.00      0.00      0.00       0.0
# ...

# %%
from sklearn.svm import SVC

# Crear el modelo SVM multiclase
modelo_svm = SVC(kernel='rbf', decision_function_shape='ovr')  # 'linear', 'poly', 'rbf'

# Entrenar
modelo_svm.fit(X_train, Y_train)

# Predecir
y_pred_svm = modelo_svm.predict(X_test)

# Evaluar
print("SVM")
print(classification_report(Y_test, y_pred_svm))
# Out:
# SVM
#               precision    recall  f1-score   support
#
#          500       0.00      0.00      0.00       1.0
#          507       0.00      0.00      0.00       1.0
#          519       0.00      0.00      0.00       1.0
#          520       0.00      0.00      0.00       1.0
#          529       0.00      0.00      0.00       0.0
#          533       0.00      0.00      0.00       1.0
#          535       0.00      0.00      0.00       1.0
#          541       0.00      0.00      0.00       1.0
#          542       0.00      0.00      0.00       1.0
#          547       0.00      0.00      0.00       1.0
#          560       0.00      0.00      0.00       0.0
#          567       0.00      0.00      0.00       1.0
#          574       0.00      0.00      0.00       1.0
#          579       0.00      0.00      0.00       1.0
#          582       0.00      0.00      0.00       1.0
#          583       0.00      0.00      0.00       1.0
# ...

# %%
from sklearn.linear_model import LogisticRegression

# Crear y entrenar el modelo de regresión logística multiclase
modelo_lr = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=500)
modelo_lr.fit(X_train, Y_train)

y_pred = modelo_lr.predict(X_test)

print("\nReporte de clasificación:")
print(classification_report(Y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#          500       0.00      0.00      0.00       1.0
#          507       0.00      0.00      0.00       1.0
#          519       0.00      0.00      0.00       1.0
#          520       0.00      0.00      0.00       1.0
#          529       0.00      0.00      0.00       0.0
#          533       0.00      0.00      0.00       1.0
#          535       0.00      0.00      0.00       1.0
#          541       0.00      0.00      0.00       1.0
#          542       0.00      0.00      0.00       1.0
#          547       0.00      0.00      0.00       1.0
#          567       0.00      0.00      0.00       1.0
# ...

# %%
X_test.columns
# Out:
# Index(['wifi', 'dual_sim', 'px_height'], dtype='object')

# %%
modelo_lr.predict([[50,10, 20]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([685])
